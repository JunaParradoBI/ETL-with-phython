# %% [markdown]
# #  Automatizacion recaudos

# %% [markdown]
# Importar librerias

# %%
import os
import datetime
import smtplib
from email.message import EmailMessage
import locale
import pandas as pd
import pyodbc

# %% [markdown]
# ## Recaudos por dia

# %% [markdown]
# Abrir conexion a SQL y guardar la informacion de query en un data frame
# * tiempo estimado 1:48 seg

# %%
# Crear una variable con el nombre de query

Query = """

SELECT top(100)*
  FROM [DW - Estados financieros].[dbo].[BalanceGeneralUnificado]

"""

# Ejecutar query


# Cadena de conexión a la base de datos SQL Server con autenticación de Windows
connection_str = (
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=localhost;"
    "DATABASE=DW - Estados financieros;"
    "Trusted_Connection=yes;"
)

# Establecer la conexión
conn = pyodbc.connect(connection_str)

try:
    # Crear un cursor
    cursor = conn.cursor()

      # Ejecutar el segundo procedimiento almacenado
    # cursor.execute("EXECUTE [Cartera].[dbo].[Solicitud_deteriorados_diarios_Grupo_Elite]")
    
    # Confirmar la ejecución si es necesario
    conn.commit() 
    
    Datos1=pd.read_sql_query(Query,conn)
    
  
    

finally:
    # Cerrar el cursor y la conexión
    cursor.close()
    conn.close()
# Out:
# C:\Users\Juan Esteban\AppData\Local\Temp\ipykernel_12336\1183301626.py:34: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   Datos1=pd.read_sql_query(Query,conn)

# %%
Datos1
# Out:
#           NIT                  Razón social de la sociedad Fecha de Corte  \
# 0   811006079                LAMINADOS TERMOFORAMDOS S A S     2018-12-31
# 1   811006300                     DULCES FLOWER Y CIA LTDA     2020-12-31
# 2   811006409                            DIESEL ANDINO S.A     2022-12-31
# 3   811006409                           DIESEL ANDINO S.A.     2018-12-31
# 4   811006409                           DIESEL ANDINO S.A.     2020-12-31
# ..        ...                                          ...            ...
# 95  811015624                  VIENTO EN POPA NUEVO S.A.S.     2020-12-31
# 96  811015643                   TECNICAS CONSTRUCTIVAS SAS     2018-12-31
# 97  811015828  INGENIERIA Y CONTRUCCION PALACIO BAENA S.A.     2018-12-31
# 98  811015828  INGENIERIA Y CONTRUCCION PALACIO BAENA S.A.     2019-12-31
# 99  811015841                            LOS MARTILLOS SAS     2021-12-31
#
#    Clasificación Industrial Internacional Uniforme Versión 4 A#C  \
# ...
